# %%
class Book:
    def __init__(self, title, author, isbn):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.is_borrowed = False

    def borrow(self):
        if not self.is_borrowed:
            self.is_borrowed = True
            print(f"The book '{self.title}' has been borrowed.")
        else:
            print(f"The book '{self.title}' is already borrowed.")

    def return_book(self):
        if self.is_borrowed:
            self.is_borrowed = False
            print(f"The book '{self.title}' has been returned.")
        else:
            print(f"The book '{self.title}' was not borrowed.")

# %%
class DigitalBook(Book):
    def __init__(self, title, author, isbn, file_format):
        super().__init__(title, author, isbn)
        self.file_format = file_format

    def borrow(self):
        super().borrow()
        if self.is_borrowed:
            print(f"The digital book '{self.title}' is now available online in {self.file_format} format.")

# %%
class AudioBook(Book):
    def __init__(self, title, author, isbn, duration):
        super().__init__(title, author, isbn)
        self.duration = duration

    def borrow(self):
        super().borrow()
        if self.is_borrowed:
            print(f"The audiobook '{self.title}' is available, duration: {self.duration} hours.")

# %%
class User:
    def __init__(self, user_id, name):
        self.user_id = user_id
        self.name = name
        self.__borrowed_books = []

    def borrow_book(self, book):
        if not book.is_borrowed:
            book.borrow()
            self.__borrowed_books.append(book)
        else:
            print(f"The book '{book.title}' is currently not available.")

    def return_book(self, book):
        if book in self.__borrowed_books:
            book.return_book()
            self.__borrowed_books.remove(book)
        else:
            print(f"The book '{book.title}' is not borrowed by {self.name}.")

# %%
class Library:
    def __init__(self, name):
        self.name = name
        self.books = []
        self.users = []

    def add_book(self, book):
        self.books.append(book)
        print(f"Book '{book.title}' added to Lib.")

    def register_user(self, user):
        self.users.append(user)
        print(f"User '{user.name}' registered to Lib.")

    def lend_book(self, user_id, isbn):
        user = self.find_user(user_id)
        book = self.find_book(isbn)
        if user and book:
            user.borrow_book(book)
        else:
            print("User or book not found.")

    def receive_return(self, user_id, isbn):
        user = self.find_user(user_id)
        book = self.find_book(isbn)
        if user and book:
            user.return_book(book)
        else:
            print("User or book not found.")

    def find_book(self, isbn):
        for book in self.books:
            if book.isbn == isbn:
                return book
        print(f"ISBN '{isbn}' not found.")
        return None

    def find_user(self, user_id):
        for user in self.users:
            if user.user_id == user_id:
                return user
        print(f"'{user_id}' not found.")
        return None

# %% [markdown]
# ## Test Case

# %%
library = Library("SMIT Library")

book = Book("Programming Fundamental", "Peter Pan", "00001")
digital_book = DigitalBook("Explore R", "Brook Khald", "00002", "md")
audio_book = AudioBook("Power of AI", "Natalia Brown", "00021", 8)

library.add_book(book)
library.add_book(digital_book)
library.add_book(audio_book)
# Out:
# Book 'Programming Fundamental' added to Lib.
# Book 'Explore R' added to Lib.
# Book 'Power of AI' added to Lib.

# %%
user01 = User("py001", "Samee")
user02 = User("py023", "Bilal")

# %%
library.register_user(user01)
library.register_user(user02)
# Out:
# User 'Samee' registered to Lib.
# User 'Bilal' registered to Lib.

# %%
library.lend_book("py001", "00001")  
library.lend_book("py001", "00002")  
library.lend_book("py023", "00021")
# Out:
# The book 'Programming Fundamental' has been borrowed.
# The book 'Explore R' has been borrowed.
# The digital book 'Explore R' is now available online in md format.
# The book 'Power of AI' has been borrowed.
# The audiobook 'Power of AI' is available, duration: 8 hours.

# %%
library.lend_book("py023", "00001")
# Out:
# The book 'Programming Fundamental' is currently not available.

# %%
library.receive_return("py001", "00001")
library.receive_return("py001", "00002")
# Out:
# The book 'Programming Fundamental' has been returned.
# The book 'Explore R' has been returned.

# %%
library.receive_return("py023", "00001")
# Out:
# The book 'Programming Fundamental' is not borrowed by Bilal.
